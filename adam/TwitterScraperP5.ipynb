# %%
pip install twitterscraper
# Out:
# Requirement already satisfied: twitterscraper in c:\users\adamr\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: bs4 in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (0.0.1)
# Requirement already satisfied: coala-utils~=0.5.0 in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (0.5.1)
# Requirement already satisfied: requests in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (2.22.0)
# Requirement already satisfied: lxml in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (4.5.0)
# Requirement already satisfied: billiard in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (3.6.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\adamr\anaconda3\lib\site-packages (from bs4->twitterscraper) (4.8.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (1.25.8)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\adamr\anaconda3\lib\site-packages (from beautifulsoup4->bs4->twitterscraper) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Our data gathering was achieved through a multi-step function. Using the query_tweets function from the twitterscraper Python library as our core, we wrote a wrapper function that would take a parameter dictionary and a list of queries, and loop through the dictionary running queries for each term.
#
# We ran 180 unique queries to get our training set, focusing on 20 COVID-related keywords either identified by our own subject-matter knowledge, or additional terms identified during our initial EDA process. We ran those 20 terms over 9 different geographic parameters, to try to look for geographic trends and identify hot-spots. We pulled over 100,000 tweets, which once we deleted duplicates, came out to 60,000 unique tweets. However, we changed problem goals after collection of the initial data, and the geographic location aspect became unnecessary.
#
# To get our testing set, we used RandomWordGenerator.com to generate 50 search terms, and regenerated our list if we got more than 5 obvious stopwords. We then ran 450 queries, using the same 9 geographic locations for consistency, to create a testing set with what we hoped would be enough unrelated noise. We pulled a dataset of
#
# Our function struggles with complications related to the way the twitterscraper library works. Unlike other Twitter query libaries we tried, the twitterscraper library doesn't require an API key to use. It circumvents the API requirement by spooling up a VPN, then using that VPN to inject your query term as a URL into Twitter's front-end web search function, and returns user-defined parameters as the results. The twitterscraper method is very inefficient compared to an API call, but circumnavigates the API limitations such as the 7-day search window.
#
# Because we are using an inherently inefficient library that places substantial resource burden on the CPU, and are then running queries in series instead of in parallel, searches using the function take a long time. For multiple queries, it can take in excess of an hour to scrape the data. We experimented with parallelization, but computer resource use became unrealistic. Running 5 queries in parallel pushed a 32-thread processor to 100% utilization, slowing query speeds even further.

# %%
#Import core function modules
import sys
import pandas as pd
import numpy as np
import datetime
import os #Library module for .csv file check
from twitterscraper import query_tweets

#---------------------------------------------------------------------

#This is a sample list of terms
'''query_list = [
    'COVID',
    'COVID-19',
    'Corona',
    'Coronavirus',
    'Quarantine',
    '#COVID',
    '#COVID-19',
    '#quarantine',
    '#Quarantine',
    '#covid19',
    '#socialdistancingnyc',
    '#socialdistancing',
    'asymptomatic',
    'contaminated',
    'spread',
    'essential',
    'medical',
    'mask',
    'n95',
    'N95',
    'antibody AND test',
    'antibody',
    'test AND positive',
    'test',
    'positive'
]'''

#The below list was generated from randomwordgenerator.com, selecting 50 words with no extra parameters
query_list = [
    'abnormal',
    'orthodox',
    'lump',
    'chocolate',
    'excavation',
    'guarantee',
    'mess',
    'prefer',
    'shift',
    'bronze',
    'tempt',
    'pace',
    'junior',
    'round',
    'guard',
    'dine',
    'wriggle',
    'bishop',
    'unlike',
    'circle',
    'opponent',
    'table',
    'departure',
    'berry',
    'midnight',
    'silk',
    'flight',
    'lion',
    'detective',
    'student',
    'hot',
    'chicken',
    'director',
    'pit',
    'gradual',
    'heroin',
    'love',
    'grimace',
    'panic',
    'accompany',
    'sale',
    'girl',
    'elect',
    'leaf',
    'other',
    'offender',
    'monster',
    'filter',
    'quotation'
]

custom_params = {'Brooklyn':{'city': 'Brooklyn',
                            'lat': 40.650002,
                            'long': -73.949997,
                            'radius': '10mi',
                            'queries': query_list,
                            'start_year': 2020,
                            'start_month': 2,
                            'start_day': 1},
                  'Manhattan': {'city' : 'Manhattan',
                             'lat': 40.758896,
                             'long': -73.985130,
                             'radius': '10mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                 'Queens': {'city' : 'Queens',
                              'lat': 40.742054,
                              'long': -73.769417,
                              'radius': '10mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'Bronx': {'city' : 'Bronx',
                              'lat': 40.829643,
                              'long': -73.926175,
                              'radius': '10mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'Hoboken': {'city' : 'Hoboken',
                              'lat': 40.7440,
                              'long': -74.0324,
                              'radius': '10mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'Jersey City': {'city' : 'Jersey City',
                              'lat': 40.7178,
                              'long': -74.0431,
                              'radius': '10mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'Westchester': {'city' : 'Westchester Co.',
                              'lat': 41.1220,
                              'long': -73.7949,
                              'radius': '20mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'East Hampton': {'city' : 'East Hampton',
                              'lat': 40.9634,
                              'long': -72.1848,
                              'radius': '20mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 2,
                             'start_day': 1},
                'NYC': {'city' : 'NYC',
                              'lat': 40.9634,
                              'long': -72.1848,
                              'radius': '35mi',
                             'queries': query_list,
                             'start_year': 2020,
                             'start_month': 1,
                             'start_day': 1}
}
#--------------------------------------------------------------------

#Get tweets without geolocation
def get_tweets(query, year, month, day): 
    tweets = {} #Instantiates a new empty dictionary
    count = 0 #Instantiates an index generator
    for tweet in query_tweets(query,begindate=datetime.date(year,month,day)):
        chirp = {} #Instantiates a new empty dictionary for each pulled tweet
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['city'] = np.NaN #Fills columns with NaNs for data cleaning at a later point. These items are NaNs so that
        chirp['lat'] = np.NaN #They will be flagged in an EDA search for missing values, instead of being strings with no information
        chirp['long'] = np.NaN
        chirp['radius'] = np.NaN
        chirp['query_start'] = pd.to_datetime(f"{year}/{month}/{day}") #Generates date as datetime object
        tweets.update({count : chirp}) #Sets count value to tweets keys, so that index is automatically generated 
        count += 1 #increments index up by 1
    return tweets
#--------------------------------------------------------------------

#Get tweets with geolocation
def get_tweets_geoloc(query, city, lat, long, radius, year, month, day): #Geolocation parameters defined by user in master function or dictionary
    tweets = {}
    count = 0
    for tweet in query_tweets(f"{query}, geocode:{lat},{long},{radius}",begindate=datetime.date(year,month,day)):
        chirp = {} #Generates tweet dictionary by calling on generated 'tweet' object attributes
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['city'] = city
        chirp['lat'] = lat
        chirp['long'] = long
        chirp['radius'] = radius
        chirp['query_start'] = pd.to_datetime(f"{year}/{month}/{day}") #Generates date as datetime object
        tweets.update({count : chirp}) #Sets count value to tweets keys, so that index is automatically generated 
        count += 1 #increments index up by 1
    return tweets
#--------------------------------------------------------------------

#Generate dataframe from "tweets" dictionary generated after each query
def make_dataframe(dictionary):
    df = pd.DataFrame.from_dict(dictionary, orient='index') #Creates a dataframe from the input dictionary 'tweets' later in function
    return df #returns a temporary dataframe for concatenation later
#--------------------------------------------------------------------

#Query function using custom parameters
def get_query_dataframe_cp(custom_params):
    query_df = pd.DataFrame() #instantiate an empty dataframe
    for key in custom_params.keys(): #Generates a new query dataframe for each city used in the parameter dictionary
        for query in custom_params[key]['queries']: #Runs a unique query for each unique term in the query key
            tweets = get_tweets_geoloc(query,custom_params[key]['city'],custom_params[key]['lat'],custom_params[key]['long'],
                                       custom_params[key]['radius'],custom_params[key]['start_year'],custom_params[key]['start_month'],
                                       custom_params[key]['start_day'])
            df = make_dataframe(tweets) #creates temporary dataframe from independent query
            query_df = pd.concat([query_df,df],ignore_index = True) #concatenates temporary dataframe 'df' to master query dataframe 
    return query_df
#Credit Danielle Medellin for the majority of this code block section
#---------------------------------------------------------------

#Query function with geolocation but no custom parameters
def get_query_dataframe_geo(list_of_queries,city,lat,long,radius,year,month,day):
    query_df = pd.DataFrame()
    for query in list_of_queries: #Runs the same functions as custom parameters code
            tweets = get_tweets_geoloc(query,city,lat,long,radius,year,month,day)
            df = make_dataframe(tweets)
            query_df = pd.concat([query_df,df],ignore_index = True)
    return query_df
#-------------------------------------------------------------------

#Query function with no custom anything
def get_query_dataframe(list_of_queries,year,month,day):
    query_df = pd.DataFrame()
    for query in list_of_queries:
            tweets = get_tweets(query,year,month,day)
            df = make_dataframe(tweets)
            query_df = pd.concat([query_df,df],ignore_index = True)
    return query_df
#------------------------------------------------------------------

#Master function
def get_dataset():   
    #Main function switches
    custom_params_switch = input("Are you using a custom parameter dictionary? (y/n)") #Enables or disables custom dictionary use in query parameter switch block
    if str.lower(custom_params_switch) != 'y': #If the user is not using parameters
        
        #Geolocation parameter configuration
        geo_switch = input("Are you using geolocation? (y/n)") #If no custom dictionary, enables or disables geolocation in query parameter switch block
        if str.lower(geo_switch) == 'y':
            lat = float(input("Input Latitude:")) #Converts string input latitude to float value
            long = float(input("Input Longitude:"))
            city = input("Input city or neighborhood corresponding to coordinates:") #Allows filling of city values
            radius = input("Input radius and unit:")
            
        #Date parameter configuration
        use_custom_start_date = input("Using custom query start? (y/n)") #Enables or disables custom date parameter
        if str.lower(use_custom_start_date) == 'y':
            year = int(input("Input start year YYYY:"))
            month = int(input("Input start month MM:"))
            day = int(input("Input start day DD:"))
        else: #Sets default date
            
            #Default date parameters. Users can change defaults here
            year = 2019
            month = 12
            day = 1
 
    #CSV export parameter configuration
    export_csv_switch = input("Do you want to export the final dataframe to csv? (y/n)")
    if str.lower(export_csv_switch) == 'y': #Enables CSV switch block later if yes as well
        custom_csv_name = input("Input CSV export file name:") #Prompts user for file name
        if os.path.exists(f'datasets/{custom_csv_name}.csv') == True: #Check if file has already been created. If yes, prompt user to overwrite or make new file.
            overwrite_check = input ("File already exists--do you want to overwrite? (y/n)")
            if str.lower(overwrite_check) != 'y': #If user uses any value except y, the function will not proceed
                new_csv_name = custom_csv_name #creates new_csv_name variable = to old name
                while new_csv_name == custom_csv_name: #continues to reject file name until a unique name is created
                    new_csv_name = input("Input new output file name:")
                custom_csv_name = new_csv_name #Sets the file name to the new user input
    
    #Query parameter switch block
    if str.lower(custom_params_switch) == 'y':
        dataset = get_query_dataframe_cp(custom_params)
    else:
        if str.lower(geo_switch) == 'y':
            dataset = get_query_dataframe_geo(query_list,city,lat,long,radius,year,month,day)
        else:
            dataset = get_query_dataframe(query_list,year,month,day)
    
    #CSV export switch block
    if str.lower(export_csv_switch) == 'y':
        if os.path.exists('datasets') != True:
            os.mkdir('datasets')
        dataset.to_csv(f"./datasets/{custom_csv_name}.csv", index = False) #write csv to datasets folder
        print(f"Export complete, scraped {len(dataset.index)} tweets") #Prints completion statement including total tweets scraped       
    else:
        return dataset
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'}

# %%
get_dataset()
# Out:
# 2020-04-09 until:2020-04-16', 'ramadan, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'ramadan, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'ramadan, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'ramadan, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 12 tweets (12 new).
# INFO: Got 16 tweets (4 new).
# INFO: Got 18 tweets (2 new).
# INFO: Got 22 tweets (4 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: Got 22 tweets (0 new).
# INFO: queries: ['mosque, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'mosque, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 2 tweets (2 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: Got 2 tweets (0 new).
# INFO: queries: ['gamer, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'gamer, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 8 tweets (8 new).
# INFO: Got 18 tweets (10 new).
# INFO: Got 38 tweets (20 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 80 tweets (22 new).
# INFO: Got 94 tweets (14 new).
# INFO: Got 104 tweets (10 new).
# INFO: Got 134 tweets (30 new).
# INFO: Got 156 tweets (22 new).
# INFO: Got 184 tweets (28 new).
# INFO: Got 204 tweets (20 new).
# INFO: Got 226 tweets (22 new).
# INFO: Got 256 tweets (30 new).
# INFO: Got 292 tweets (36 new).
# INFO: Got 318 tweets (26 new).
# INFO: Got 352 tweets (34 new).
# INFO: Got 390 tweets (38 new).
# INFO: Got 427 tweets (37 new).
# INFO: Got 481 tweets (54 new).
# INFO: Got 610 tweets (129 new).
# INFO: queries: ['laundry, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'laundry, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 2 tweets (2 new).
# INFO: Got 6 tweets (4 new).
# INFO: Got 10 tweets (4 new).
# INFO: Got 12 tweets (2 new).
# INFO: Got 14 tweets (2 new).
# INFO: Got 16 tweets (2 new).
# INFO: Got 18 tweets (2 new).
# INFO: Got 28 tweets (10 new).
# INFO: Got 46 tweets (18 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: Got 46 tweets (0 new).
# INFO: queries: ['rangers, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'rangers, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 2 tweets (2 new).
# INFO: Got 8 tweets (6 new).
# INFO: Got 10 tweets (2 new).
# INFO: Got 14 tweets (4 new).
# INFO: Got 18 tweets (4 new).
# INFO: Got 28 tweets (10 new).
# INFO: Got 34 tweets (6 new).
# INFO: Got 36 tweets (2 new).
# INFO: Got 38 tweets (2 new).
# INFO: Got 42 tweets (4 new).
# INFO: Got 44 tweets (2 new).
# INFO: Got 58 tweets (14 new).
# INFO: Got 64 tweets (6 new).
# INFO: Got 78 tweets (14 new).
# INFO: Got 78 tweets (0 new).
# INFO: Got 78 tweets (0 new).
# INFO: Got 78 tweets (0 new).
# INFO: Got 78 tweets (0 new).
# INFO: Got 78 tweets (0 new).
# INFO: Got 78 tweets (0 new).
# INFO: queries: ['books, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'books, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'books, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'books, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'books, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'books, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'books, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'books, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'books, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'books, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'books, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'books, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'books, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'books, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'books, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'books, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'books, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'books, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'books, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'books, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 14 tweets (14 new).
# INFO: Got 38 tweets (24 new).
# INFO: Got 56 tweets (18 new).
# INFO: Got 90 tweets (34 new).
# INFO: Got 112 tweets (22 new).
# INFO: Got 144 tweets (32 new).
# INFO: Got 180 tweets (36 new).
# INFO: Got 212 tweets (32 new).
# INFO: Got 242 tweets (30 new).
# INFO: Got 280 tweets (38 new).
# INFO: Got 324 tweets (44 new).
# INFO: Got 366 tweets (42 new).
# INFO: Got 413 tweets (47 new).
# INFO: Got 455 tweets (42 new).
# INFO: Got 505 tweets (50 new).
# INFO: Got 550 tweets (45 new).
# INFO: Got 595 tweets (45 new).
# INFO: Got 642 tweets (47 new).
# INFO: Got 707 tweets (65 new).
# INFO: Got 902 tweets (195 new).
# INFO: queries: ['nyc, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'nyc, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 10 tweets (10 new).
# INFO: Got 18 tweets (8 new).
# INFO: Got 34 tweets (16 new).
# INFO: Got 48 tweets (14 new).
# INFO: Got 62 tweets (14 new).
# INFO: Got 74 tweets (12 new).
# INFO: Got 92 tweets (18 new).
# INFO: Got 104 tweets (12 new).
# INFO: Got 130 tweets (26 new).
# INFO: Got 158 tweets (28 new).
# INFO: Got 194 tweets (36 new).
# INFO: Got 226 tweets (32 new).
# INFO: Got 267 tweets (41 new).
# INFO: Got 308 tweets (41 new).
# INFO: Got 361 tweets (53 new).
# INFO: Got 408 tweets (47 new).
# INFO: Got 455 tweets (47 new).
# INFO: Got 507 tweets (52 new).
# INFO: Got 563 tweets (56 new).
# INFO: Got 649 tweets (86 new).
# INFO: queries: ['new york, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'new york, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'new york, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'new york, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'new york, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'new york, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'new york, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'new york, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'new york, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'new york, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'new york, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'new york, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'new york, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'new york, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'new york, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'new york, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'new york, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'new york, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'new york, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'new york, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 95 tweets (95 new).
# INFO: Got 186 tweets (91 new).
# INFO: Got 272 tweets (86 new).
# INFO: Got 368 tweets (96 new).
# INFO: Got 476 tweets (108 new).
# INFO: Got 578 tweets (102 new).
# INFO: Got 692 tweets (114 new).
# INFO: Got 815 tweets (123 new).
# INFO: Got 931 tweets (116 new).
# INFO: Got 1055 tweets (124 new).
# INFO: Got 1194 tweets (139 new).
# INFO: Got 1323 tweets (129 new).
# INFO: Got 1477 tweets (154 new).
# INFO: Got 1636 tweets (159 new).
# INFO: Got 1775 tweets (139 new).
# INFO: Got 1915 tweets (140 new).
# INFO: Got 2073 tweets (158 new).
# INFO: Got 2213 tweets (140 new).
# INFO: Got 2373 tweets (160 new).
# INFO: Got 2512 tweets (139 new).
# INFO: queries: ['#newyork, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', '#newyork, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 14 tweets (14 new).
# INFO: Got 21 tweets (7 new).
# INFO: Got 27 tweets (6 new).
# INFO: Got 30 tweets (3 new).
# INFO: Got 35 tweets (5 new).
# INFO: Got 37 tweets (2 new).
# INFO: Got 52 tweets (15 new).
# INFO: Got 58 tweets (6 new).
# INFO: Got 64 tweets (6 new).
# INFO: Got 73 tweets (9 new).
# INFO: Got 86 tweets (13 new).
# INFO: Got 93 tweets (7 new).
# INFO: Got 94 tweets (1 new).
# INFO: Got 102 tweets (8 new).
# INFO: Got 108 tweets (6 new).
# INFO: Got 117 tweets (9 new).
# INFO: Got 133 tweets (16 new).
# INFO: Got 140 tweets (7 new).
# INFO: Got 145 tweets (5 new).
# INFO: Got 157 tweets (12 new).
# INFO: queries: ['giants, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'giants, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'giants, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'giants, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'giants, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-03', 'giants, geocode:40.9634,-72.1848,35mi since:2020-02-03 until:2020-02-09', 'giants, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-16', 'giants, geocode:40.9634,-72.1848,35mi since:2020-02-16 until:2020-02-23', 'giants, geocode:40.9634,-72.1848,35mi since:2020-02-23 until:2020-02-29', 'giants, geocode:40.9634,-72.1848,35mi since:2020-02-29 until:2020-03-07', 'giants, geocode:40.9634,-72.1848,35mi since:2020-03-07 until:2020-03-14', 'giants, geocode:40.9634,-72.1848,35mi since:2020-03-14 until:2020-03-20', 'giants, geocode:40.9634,-72.1848,35mi since:2020-03-20 until:2020-03-27', 'giants, geocode:40.9634,-72.1848,35mi since:2020-03-27 until:2020-04-03', 'giants, geocode:40.9634,-72.1848,35mi since:2020-04-03 until:2020-04-09', 'giants, geocode:40.9634,-72.1848,35mi since:2020-04-09 until:2020-04-16', 'giants, geocode:40.9634,-72.1848,35mi since:2020-04-16 until:2020-04-23', 'giants, geocode:40.9634,-72.1848,35mi since:2020-04-23 until:2020-04-29', 'giants, geocode:40.9634,-72.1848,35mi since:2020-04-29 until:2020-05-06', 'giants, geocode:40.9634,-72.1848,35mi since:2020-05-06 until:2020-05-13']
# INFO: Got 2 tweets (2 new).
# INFO: Got 4 tweets (2 new).
# INFO: Got 9 tweets (5 new).
# INFO: Got 14 tweets (5 new).
# INFO: Got 16 tweets (2 new).
# INFO: Got 17 tweets (1 new).
# INFO: Got 25 tweets (8 new).
# INFO: Got 30 tweets (5 new).
# INFO: Got 47 tweets (17 new).
# INFO: Got 48 tweets (1 new).
# INFO: Got 52 tweets (4 new).
# INFO: Got 60 tweets (8 new).
# INFO: Got 73 tweets (13 new).
# INFO: Got 77 tweets (4 new).
# INFO: Got 81 tweets (4 new).
# INFO: Got 82 tweets (1 new).
# INFO: Got 84 tweets (2 new).
# INFO: Got 87 tweets (3 new).
# INFO: Got 105 tweets (18 new).
# INFO: Got 107 tweets (2 new).
# Export complete, scraped 57942 tweets
