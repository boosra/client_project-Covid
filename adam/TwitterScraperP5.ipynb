# %%
pip install twitterscraper
# Out:
# Requirement already satisfied: twitterscraper in c:\users\adamr\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: billiard in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (3.6.3.0)
# Requirement already satisfied: bs4 in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (0.0.1)
# Requirement already satisfied: lxml in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (4.5.0)
# Requirement already satisfied: requests in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (2.22.0)
# Requirement already satisfied: coala-utils~=0.5.0 in c:\users\adamr\anaconda3\lib\site-packages (from twitterscraper) (0.5.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\adamr\anaconda3\lib\site-packages (from bs4->twitterscraper) (4.8.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\adamr\anaconda3\lib\site-packages (from requests->twitterscraper) (1.25.8)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\adamr\anaconda3\lib\site-packages (from beautifulsoup4->bs4->twitterscraper) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import core function modules
import sys
import pandas as pd
import numpy as np
import datetime
import os #Library module for .csv file check
from twitterscraper import query_tweets

#---------------------------------------------------------------------

#This is a sample list of terms
query_list = [
    'COVID',
    'COVID-19',
    'Corona',
    'Coronavirus',
    'Quarantine',
    '#COVID',
    '#COVID-19',
    '#quarantine',
    '#Quarantine',
    '#covid19'
]
#--------------------------------------------------------------------

#This is a sample filled-out custom parameter dictionary.
custom_params = {'Brooklyn':{'city': 'Brooklyn',
                         'lat': 40.650002,
                         'long': -73.949997,
                         'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,                                               
                         'start_month': 2,
                         'start_day': 1},
              'Manhattan': {'city' : 'Manhattan',
                          'lat': 40.758896,
                          'long': -73.985130,
                          'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
             'Queens': {'city' : 'Queens',
                          'lat': 40.742054,
                          'long': -73.769417,
                          'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'Bronx': {'city' : 'Bronx',
                          'lat': 40.829643,
                          'long': -73.926175,
                          'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'Hoboken': {'city' : 'Hoboken',
                          'lat': 40.7440,
                          'long': -74.0324,
                          'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'Jersey City': {'city' : 'Jersey City',
                          'lat': 40.7178,
                          'long': -74.0431,
                          'radius': '10mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'Westchester': {'city' : 'Westchester Co.',
                          'lat': 41.1220,
                          'long': -73.7949,
                          'radius': '20mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'East Hampton': {'city' : 'East Hampton',
                          'lat': 40.9634,
                          'long': -72.1848,
                          'radius': '20mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 2,
                         'start_day': 1},
            'NYC': {'city' : 'NYC',
                          'lat': 40.9634,
                          'long': -72.1848,
                          'radius': '35mi',
                         'queries': query_list,
                         'start_year': 2020,
                         'start_month': 1,
                         'start_day': 1}
             }

#Credit to Danielle Medellin, DSI11-NYC for assisting in implementation of custom parameter dictionary support
#--------------------------------------------------------------------

#Get tweets without geolocation
def get_tweets(query, year, month, day): 
    tweets = {} #Instantiates a new empty dictionary
    count = 0 #Instantiates an index generator
    for tweet in query_tweets(query,begindate=datetime.date(year,month,day)):
        chirp = {} #Instantiates a new empty dictionary for each pulled tweet
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['city'] = np.NaN #Fills columns with NaNs for data cleaning at a later point. These items are NaNs so that
        chirp['lat'] = np.NaN #They will be flagged in an EDA search for missing values, instead of being strings with no information
        chirp['long'] = np.NaN
        chirp['radius'] = np.NaN
        chirp['query_start'] = pd.to_datetime(f"{year}/{month}/{day}") #Generates date as datetime object
        tweets.update({count : chirp}) #Sets count value to tweets keys, so that index is automatically generated 
        count += 1 #increments index up by 1
    return tweets
#--------------------------------------------------------------------

#Get tweets with geolocation
def get_tweets_geoloc(query, city, lat, long, radius, year, month, day): #Geolocation parameters defined by user in master function or dictionary
    tweets = {}
    count = 0
    for tweet in query_tweets(f"{query}, geocode:{lat},{long},{radius}",begindate=datetime.date(year,month,day)):
        chirp = {} #Generates tweet dictionary by calling on generated 'tweet' object attributes
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['city'] = city
        chirp['lat'] = lat
        chirp['long'] = long
        chirp['radius'] = radius
        chirp['query_start'] = pd.to_datetime(f"{year}/{month}/{day}") #Generates date as datetime object
        tweets.update({count : chirp}) #Sets count value to tweets keys, so that index is automatically generated 
        count += 1 #increments index up by 1
    return tweets
#--------------------------------------------------------------------

#Generate dataframe from "tweets" dictionary generated after each query
def make_dataframe(dictionary):
    df = pd.DataFrame.from_dict(dictionary, orient='index') #Creates a dataframe from the input dictionary 'tweets' later in function
    return df #returns a temporary dataframe for concatenation later
#--------------------------------------------------------------------

#Query function using custom parameters
def get_query_dataframe_cp(custom_params):
    query_df = pd.DataFrame() #instantiate an empty dataframe
    for key in custom_params.keys(): #Generates a new query dataframe for each city used in the parameter dictionary
        for query in custom_params[key]['queries']: #Runs a unique query for each unique term in the query key
            tweets = get_tweets_geoloc(query,custom_params[key],custom_params[key]['lat'],custom_params[key]['long'],
                                       custom_params[key]['radius'],custom_params[key]['start_year'],custom_params[key]['start_month'],
                                       custom_params[key]['start_day'])
            df = make_dataframe(tweets) #creates temporary dataframe from independent query
            query_df = pd.concat([query_df,df],ignore_index = True) #concatenates temporary dataframe 'df' to master query dataframe 
    return query_df
#Credit Danielle Medellin for the majority of this code block section
#---------------------------------------------------------------

#Query function with geolocation but no custom parameters
def get_query_dataframe_geo(list_of_queries,city,lat,long,radius,year,month,day):
    query_df = pd.DataFrame()
    for query in list_of_queries: #Runs the same functions as custom parameters code
            tweets = get_tweets_geoloc(query,city,lat,long,radius,year,month,day)
            df = make_dataframe(tweets)
            query_df = pd.concat([query_df,df],ignore_index = True)
    return query_df
#-------------------------------------------------------------------

#Query function with no custom anything
def get_query_dataframe(list_of_queries,year,month,day):
    query_df = pd.DataFrame()
    for query in list_of_queries:
            tweets = get_tweets(query,year,month,day)
            df = make_dataframe(tweets)
            query_df = pd.concat([query_df,df],ignore_index = True)
    return query_df
#------------------------------------------------------------------

#Master function
def get_dataset():   
    #Main function switches
    custom_params_switch = input("Are you using a custom parameter dictionary? (y/n)") #Enables or disables custom dictionary use in query parameter switch block
    if str.lower(custom_params_switch) != 'y': #If the user is not using parameters
        
        #Geolocation parameter configuration
        geo_switch = input("Are you using geolocation? (y/n)") #If no custom dictionary, enables or disables geolocation in query parameter switch block
        if str.lower(geo_switch) == 'y':
            lat = float(input("Input Latitude:")) #Converts string input latitude to float value
            long = float(input("Input Longitude:"))
            city = input("Input city or neighborhood corresponding to coordinates:") #Allows filling of city values
            radius = input("Input radius and unit:")
            
        #Date parameter configuration
        use_custom_start_date = input("Using custom query start? (y/n)") #Enables or disables custom date parameter
        if str.lower(use_custom_start_date) == 'y':
            year = int(input("Input start year YYYY:"))
            month = int(input("Input start month MM:"))
            day = int(input("Input start day DD:"))
        else: #Sets default date
            
            #Default date parameters. Users can change defaults here
            year = 2019
            month = 12
            day = 1
 
    #CSV export parameter configuration
    export_csv_switch = input("Do you want to export the final dataframe to csv? (y/n)")
    if str.lower(export_csv_switch) == 'y': #Enables CSV switch block later if yes as well
        custom_csv_name = input("Input CSV export file name:") #Prompts user for file name
        if os.path.exists(f'datasets/{custom_csv_name}.csv') == True: #Check if file has already been created. If yes, prompt user to overwrite or make new file.
            overwrite_check = input ("File already exists--do you want to overwrite? (y/n)")
            if str.lower(overwrite_check) != 'y': #If user uses any value except y, the function will not proceed
                new_csv_name = custom_csv_name #creates new_csv_name variable = to old name
                while new_csv_name == custom_csv_name: #continues to reject file name until a unique name is created
                    new_csv_name = input("Input new output file name:")
                custom_csv_name = new_csv_name #Sets the file name to the new user input
    
    #Query parameter switch block
    if str.lower(custom_params_switch) == 'y':
        dataset = get_query_dataframe_cp(custom_params)
    else:
        if str.lower(geo_switch) == 'y':
            dataset = get_query_dataframe_geo(query_list,city,lat,long,radius,year,month,day)
        else:
            dataset = get_query_dataframe(query_list,year,month,day)
    
    #CSV export switch block
    if str.lower(export_csv_switch) == 'y':
        if os.path.exists('datasets') != True:
            os.mkdir('datasets')
        dataset.to_csv(f"./datasets/{custom_csv_name}.csv", index = False) #write csv to datasets folder
        print(f"Export complete, scraped {len(dataset.index)} tweets") #Prints completion statement including total tweets scraped       
    else:
        return dataset
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows NT 5.2; RW; rv:7.0a1) Gecko/20091211 SeaMonkey/9.23a1pre'}

# %%
get_dataset()
# Out:
# (20 new).
# INFO: Got 122 tweets (18 new).
# INFO: Got 142 tweets (20 new).
# INFO: Got 162 tweets (20 new).
# INFO: Got 181 tweets (19 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: Got 181 tweets (0 new).
# INFO: queries: ['COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', 'COVID-19, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 18 tweets (18 new).
# INFO: Got 27 tweets (9 new).
# INFO: Got 47 tweets (20 new).
# INFO: Got 66 tweets (19 new).
# INFO: Got 84 tweets (18 new).
# INFO: Got 104 tweets (20 new).
# INFO: Got 122 tweets (18 new).
# INFO: Got 140 tweets (18 new).
# INFO: Got 157 tweets (17 new).
# INFO: Got 175 tweets (18 new).
# INFO: Got 177 tweets (2 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: Got 177 tweets (0 new).
# INFO: queries: ['Corona, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', 'Corona, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 12 tweets (12 new).
# INFO: Got 32 tweets (20 new).
# INFO: Got 34 tweets (2 new).
# INFO: Got 48 tweets (14 new).
# INFO: Got 66 tweets (18 new).
# INFO: Got 73 tweets (7 new).
# INFO: Got 74 tweets (1 new).
# INFO: Got 86 tweets (12 new).
# INFO: Got 102 tweets (16 new).
# INFO: Got 110 tweets (8 new).
# INFO: Got 111 tweets (1 new).
# INFO: Got 131 tweets (20 new).
# INFO: Got 146 tweets (15 new).
# INFO: Got 147 tweets (1 new).
# INFO: Got 167 tweets (20 new).
# INFO: Got 167 tweets (0 new).
# INFO: Got 167 tweets (0 new).
# INFO: Got 167 tweets (0 new).
# INFO: Got 167 tweets (0 new).
# INFO: Got 167 tweets (0 new).
# INFO: queries: ['Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', 'Coronavirus, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 5 tweets (5 new).
# INFO: Got 7 tweets (2 new).
# INFO: Got 27 tweets (20 new).
# INFO: Got 33 tweets (6 new).
# INFO: Got 38 tweets (5 new).
# INFO: Got 58 tweets (20 new).
# INFO: Got 64 tweets (6 new).
# INFO: Got 84 tweets (20 new).
# INFO: Got 103 tweets (19 new).
# INFO: Got 123 tweets (20 new).
# INFO: Got 143 tweets (20 new).
# INFO: Got 162 tweets (19 new).
# INFO: Got 181 tweets (19 new).
# INFO: Got 200 tweets (19 new).
# INFO: Got 219 tweets (19 new).
# INFO: Got 237 tweets (18 new).
# INFO: Got 257 tweets (20 new).
# INFO: Got 257 tweets (0 new).
# INFO: Got 257 tweets (0 new).
# INFO: Got 257 tweets (0 new).
# INFO: queries: ['Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', 'Quarantine, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 3 tweets (3 new).
# INFO: Got 23 tweets (20 new).
# INFO: Got 24 tweets (1 new).
# INFO: Got 42 tweets (18 new).
# INFO: Got 44 tweets (2 new).
# INFO: Got 64 tweets (20 new).
# INFO: Got 84 tweets (20 new).
# INFO: Got 104 tweets (20 new).
# INFO: Got 123 tweets (19 new).
# INFO: Got 141 tweets (18 new).
# INFO: Got 159 tweets (18 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 159 tweets (0 new).
# INFO: Got 195 tweets (36 new).
# INFO: queries: ['#COVID, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', '#COVID, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 18 tweets (18 new).
# INFO: Got 22 tweets (4 new).
# INFO: Got 24 tweets (2 new).
# INFO: Got 26 tweets (2 new).
# INFO: Got 44 tweets (18 new).
# INFO: Got 48 tweets (4 new).
# INFO: Got 60 tweets (12 new).
# INFO: Got 68 tweets (8 new).
# INFO: Got 107 tweets (39 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: Got 107 tweets (0 new).
# INFO: queries: ['#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', '#COVID-19, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 2 tweets (2 new).
# INFO: Got 6 tweets (4 new).
# INFO: Got 51 tweets (45 new).
# INFO: Got 102 tweets (51 new).
# INFO: Got 142 tweets (40 new).
# INFO: Got 200 tweets (58 new).
# INFO: Got 254 tweets (54 new).
# INFO: Got 317 tweets (63 new).
# INFO: Got 387 tweets (70 new).
# INFO: Got 461 tweets (74 new).
# INFO: Got 699 tweets (238 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: Got 699 tweets (0 new).
# INFO: queries: ['#quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', '#quarantine, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 18 tweets (18 new).
# INFO: Got 38 tweets (20 new).
# INFO: Got 56 tweets (18 new).
# INFO: Got 82 tweets (26 new).
# INFO: Got 98 tweets (16 new).
# INFO: Got 118 tweets (20 new).
# INFO: Got 142 tweets (24 new).
# INFO: Got 172 tweets (30 new).
# INFO: Got 232 tweets (60 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: queries: ['#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', '#Quarantine, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 20 tweets (20 new).
# INFO: Got 36 tweets (16 new).
# INFO: Got 56 tweets (20 new).
# INFO: Got 74 tweets (18 new).
# INFO: Got 98 tweets (24 new).
# INFO: Got 116 tweets (18 new).
# INFO: Got 142 tweets (26 new).
# INFO: Got 172 tweets (30 new).
# INFO: Got 232 tweets (60 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: Got 232 tweets (0 new).
# INFO: queries: ['#covid19, geocode:40.9634,-72.1848,35mi since:2020-01-01 until:2020-01-07', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-01-07 until:2020-01-14', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-01-14 until:2020-01-20', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-01-20 until:2020-01-27', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-01-27 until:2020-02-02', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-02-02 until:2020-02-09', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-02-09 until:2020-02-15', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-02-15 until:2020-02-22', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-02-22 until:2020-02-28', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-02-28 until:2020-03-06', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-03-06 until:2020-03-12', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-03-12 until:2020-03-19', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-03-19 until:2020-03-25', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-03-25 until:2020-04-01', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-04-01 until:2020-04-07', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-04-07 until:2020-04-14', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-04-14 until:2020-04-20', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-04-20 until:2020-04-27', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-04-27 until:2020-05-03', '#covid19, geocode:40.9634,-72.1848,35mi since:2020-05-03 until:2020-05-10']
# INFO: Got 2 tweets (2 new).
# INFO: Got 16 tweets (14 new).
# INFO: Got 70 tweets (54 new).
# INFO: Got 118 tweets (48 new).
# INFO: Got 165 tweets (47 new).
# INFO: Got 218 tweets (53 new).
# INFO: Got 278 tweets (60 new).
# INFO: Got 346 tweets (68 new).
# INFO: Got 416 tweets (70 new).
# INFO: Got 464 tweets (48 new).
# INFO: Got 612 tweets (148 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# INFO: Got 612 tweets (0 new).
# Export complete, scraped 51192 tweets
